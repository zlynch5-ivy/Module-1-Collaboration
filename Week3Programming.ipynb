# %%
things = ["mozzarella", "cinderella", "salmonella"]
print(things)
# Out:
# ['mozzarella', 'cinderella', 'salmonella']

# %%
things = ["mozzarella", "Cinderella", "salmonella"]
print(things)
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %%
things = ["MOZZARELLA", "Cinderella", "salmonella"]
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella', 'salmonella']

# %%
things = ["MOZZARELLA", "Cinderella"]
print(f"{things}, Nobel Prize obtained!")

# %%
def good():
    others = ["Harry", "Ron", "Hermione"]

# %%
def get_odds():
    count = 0
    odds = list()
    for number in range(1, 10):
        num = number
        oddnum = num % 2
        if oddnum == 1:
            odds.append(num)

    count = 0
    for a in odds:
        if count == 2:
            print(odds[count])
            break
        else:
            count += 1

get_odds()
# Out:
# 5
